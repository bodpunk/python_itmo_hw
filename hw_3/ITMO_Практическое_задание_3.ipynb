# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')

# %cd gdrive/MyDrive/ITMO_HW/
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/MyDrive/ITMO_HW/'
# /content/gdrive/MyDrive/ITMO_HW

# %%
#считываем файл в датафрейм
df = pd.read_csv('train.csv')

# %%
#общая информация о датасете
df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
# ...

# %%
#процент выживаемости в разрезе по классу
df.groupby('Pclass')['Survived'].mean().apply(lambda x: x * 100)
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
#самое популярное женское и мужское имя
#ТЗ не до конца понятно, имя - это значение Name целиком, или только то, что до зпт (или ещё что-то)?
#Первый вариант бессмысленный, т.к. все значения уникальные, поэтому беру только значение до зпт

#создазим копию df, в которой обрежем имя до зпт
df_nameShort = df
df_nameShort['Name'] = df_nameShort['Name'].str.split(",").str[0]

#решение
df_nameShort.groupby('Sex')['Name'].agg(lambda x: x.mode()[0])
# Out:
# Sex
# female    Andersson
# male         Panula
# Name: Name, dtype: object

# %%
#Аналогично предыдущему блоку, но с разрезом до класса
df_nameShort.groupby(['Sex', 'Pclass'])['Name'].agg(lambda x: x.mode()[0])
# Out:
# Sex     Pclass
# female  1           Allison
#         2             Brown
#         3         Andersson
# male    1            Carter
#         2           Hickman
#         3            Panula
# Name: Name, dtype: object

# %%
#часть таблицы с пассажирами, возраст которых больше 44 лет
df[df['Age'] > 44]
# Out:
#      PassengerId  Survived  Pclass             Name     Sex   Age  SibSp  \
# 6              7         0       1         McCarthy    male  54.0      0
# 11            12         1       1          Bonnell  female  58.0      0
# 15            16         1       2          Hewlett  female  55.0      0
# 33            34         0       2          Wheadon    male  66.0      0
# 52            53         1       1           Harper  female  49.0      1
# ..           ...       ...     ...              ...     ...   ...    ...
# 857          858         1       1             Daly    male  51.0      0
# 862          863         1       1            Swift  female  48.0      0
# 871          872         1       1         Beckwith  female  47.0      1
# 873          874         0       3  Vander Cruyssen    male  47.0      0
# 879          880         1       1           Potter  female  56.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# ...

# %%
#часть таблицы с пассажирами, возраст которых меньше 44 лет, и которые мужского пола
df[(df['Age'] > 44) & (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 6              7         0       1         McCarthy  male  54.0      0      0
# 33            34         0       2          Wheadon  male  66.0      0      0
# 54            55         0       1            Ostby  male  65.0      0      1
# 62            63         0       1           Harris  male  45.0      1      0
# 92            93         0       1          Chaffee  male  46.0      1      0
# ..           ...       ...     ...              ...   ...   ...    ...    ...
# 771          772         0       3           Jensen  male  48.0      0      0
# 789          790         0       1       Guggenheim  male  46.0      0      0
# 851          852         0       3         Svensson  male  74.0      0      0
# 857          858         1       1             Daly  male  51.0      0      0
# 873          874         0       3  Vander Cruyssen  male  47.0      0      0
#
# ...

# %%
#количества n-местных кабин (в которых было 2, 3, 4, ... человека)
#если правильно понял задание, то 1-местные кабины исключаем
#создадим Series, индексом которого будет кол-во мест, и выведем индекс > 1
s = df.groupby('Cabin')['Cabin'].count().value_counts()
s[s.index > 1]
# Out:
# Cabin
# 2    38
# 3     5
# 4     3
# Name: count, dtype: int64
